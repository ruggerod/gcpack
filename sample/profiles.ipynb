# %%
import numpy as np
from astropy.table import Table, Column
import sys
import matplotlib.pyplot as plt

sys.path.append('../test/')
sys.path.append('../')
import gcpack as gcp
import limepy
from sample_cluster import limepy_cluster
from plot_utils import plot_vel_disp_prof, plot_count_dens_prof, plot_vel_disp_mass_prof

# %% [markdown]
# # Test cluster

# %%
tab = limepy_cluster(10000, seed=0, phi0=7, g=1, M=33070, rh=2.5)
s = gcp.Snapshot(tab)

# %% [markdown]
# ## Plot profiles

# %%
r, sig, dsig = gcp.velocity_dispersion_profile(s)
plot_vel_disp_prof(r, sig, dsig, units={'rstar': 1., 'vstar': 1.})

# %%
m, sig, dsig = gcp.velocity_dispersion_mass_profile(s)
plot_vel_disp_mass_prof(m[:-1], sig[:-1], dsig[:-1], units={'mstar': 1})

# %%
r, d = gcp.density_profile(s)
plot_count_dens_prof(r, d, units={'rstar': 1})
